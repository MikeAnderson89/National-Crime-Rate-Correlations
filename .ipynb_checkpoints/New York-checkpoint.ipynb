# %%
#import Dependencies
import pandas as pd
import numpy as np
import json
import requests
import matplotlib.pyplot as plt
#from sodapy import Socrata (not working, though sodapy is installed to python3 via pip3)
import warnings
warnings.filterwarnings('ignore')

# %%
#Getting the URL for the JSON Request
city = "New York, New York"
url = "https://odn.data.socrata.com/resource/h4kz-unyt.json?name=" + city
data = requests.get(url).json()

# %%
#Putting data into DataFrame
data_df = pd.DataFrame(data)
data_df.head()
# Out:
#                              crime_type                id  \
# 0                         Forcible rape  1600000US3651000
# 1  Murder and nonnegligent manslaughter  1600000US3651000
# 2                   Motor vehicle theft  1600000US3651000
# 3                               Larceny  1600000US3651000
# 4                   Motor vehicle theft  1600000US3651000
#
#                                                  key                name  \
# 0        1600000US3651000--2008--Forcible rape--rate  New York, New York
# 1  1600000US3651000--2007--Murder and nonnegligen...  New York, New York
# 2  1600000US3651000--2007--Motor vehicle theft--rate  New York, New York
# 3              1600000US3651000--2009--Larceny--rate  New York, New York
# 4  1600000US3651000--2010--Motor vehicle theft--c...  New York, New York
#
#      place_name   type               value variable  year
# 0  New York, NY  place  10.664973052968367     rate  2008
# 1  New York, NY  place                 496    count  2007
# 2  New York, NY  place  161.26136165123071     rate  2007
# 3  New York, NY  place  1339.4506093211126     rate  2009
# 4  New York, NY  place               10319    count  2010

# %%
#Sorting by year
data_df = data_df.sort_values('year')
data_df.head()
# Out:
#         crime_type                id  \
# 115  Violent crime  1600000US3651000
# 141     All Crimes  1600000US3651000
# 102       Burglary  1600000US3651000
# 99         Larceny  1600000US3651000
# 155  Forcible rape  1600000US3651000
#
#                                              key                name  \
# 115  1600000US3651000--2006--Violent crime--rate  New York, New York
# 141    1600000US3651000--2006--All Crimes--count  New York, New York
# 102       1600000US3651000--2006--Burglary--rate  New York, New York
# 99        1600000US3651000--2006--Larceny--count  New York, New York
# 155  1600000US3651000--2006--Forcible rape--rate  New York, New York
#
#        place_name   type               value variable  year
# 115  New York, NY  place    637.917864308896     rate  2006
# 141  New York, NY  place              411044    count  2006
# 102  New York, NY  place   271.1206036594484     rate  2006
# 99   New York, NY  place              115363    count  2006
# 155  New York, NY  place  13.116961038951496     rate  2006

# %%
#Create dataframe for crime rate variable
crime_rate_df = data_df.loc[data_df['variable'] == 'rate']
crime_rate_df.head()
# Out:
#                                crime_type                id  \
# 115                         Violent crime  1600000US3651000
# 102                              Burglary  1600000US3651000
# 155                         Forcible rape  1600000US3651000
# 161  Murder and nonnegligent manslaughter  1600000US3651000
# 39                         Property crime  1600000US3651000
#
#                                                    key                name  \
# 115        1600000US3651000--2006--Violent crime--rate  New York, New York
# 102             1600000US3651000--2006--Burglary--rate  New York, New York
# 155        1600000US3651000--2006--Forcible rape--rate  New York, New York
# 161  1600000US3651000--2006--Murder and nonnegligen...  New York, New York
# 39        1600000US3651000--2006--Property crime--rate  New York, New York
#
#        place_name   type               value variable  year
# 115  New York, NY  place    637.917864308896     rate  2006
# 102  New York, NY  place   271.1206036594484     rate  2006
# 155  New York, NY  place  13.116961038951496     rate  2006
# 161  New York, NY  place   7.299447973123335     rate  2006
# 39   New York, NY  place  1879.1914416177046     rate  2006

# %%
#Violent Crime filtering
violent_crime_df = crime_rate_df.loc[crime_rate_df['crime_type'] == 'Violent crime']
violent_crime_df.head()
# Out:
#         crime_type                id  \
# 115  Violent crime  1600000US3651000
# 80   Violent crime  1600000US3651000
# 126  Violent crime  1600000US3651000
# 5    Violent crime  1600000US3651000
# 88   Violent crime  1600000US3651000
#
#                                              key                name  \
# 115  1600000US3651000--2006--Violent crime--rate  New York, New York
# 80   1600000US3651000--2007--Violent crime--rate  New York, New York
# 126  1600000US3651000--2008--Violent crime--rate  New York, New York
# 5    1600000US3651000--2009--Violent crime--rate  New York, New York
# 88   1600000US3651000--2010--Violent crime--rate  New York, New York
#
#        place_name   type              value variable  year
# 115  New York, NY  place   637.917864308896     rate  2006
# 80   New York, NY  place  613.7688201108587     rate  2007
# 126  New York, NY  place  580.3422977025372     rate  2008
# 5    New York, NY  place   551.809465335112     rate  2009
# 88   New York, NY  place  581.6817222452681     rate  2010

# %%
#More violent crime filtering
violent_crime_df = violent_crime_df[['year','crime_type', 'value', 'variable']]

# %%
#Converting the correct columns to numbers, not objects
violent_crime_df['year'] = pd.to_numeric(violent_crime_df['year'])
violent_crime_df['value'] = pd.to_numeric(violent_crime_df['value'])

# %%
#Plot the graph
violent_crime_df.plot(kind='line', x='year', y='value', figsize=(15,10), color='blue')
plt.xlim(2010, 2017)
plt.title('Crime Rate per 100,000 people')
plt.xlabel('Year')
plt.ylabel('Rate (Per 100,000 People)')
# Out:
# Text(0, 0.5, 'Rate (Per 100,000 People)')
