# %%
import pandas as pd
import numpy as np
import json
import requests
import matplotlib.pyplot as plt

# %%
#Getting the URL for the JSON Request
city = "Chicago, Illinois"
url = "https://odn.data.socrata.com/resource/h4kz-unyt.json?name=" + city
data = requests.get(url).json()

Crime_DF = pd.DataFrame(data)
Crime_DF.head()
# Out:
#                              crime_type                id  \
# 0                            All Crimes  1600000US1714000
# 1  Murder and nonnegligent manslaughter  1600000US1714000
# 2                    Aggravated assault  1600000US1714000
# 3  Murder and nonnegligent manslaughter  1600000US1714000
# 4                              Burglary  1600000US1714000
#
#                                                  key               name  \
# 0          1600000US1714000--2010--All Crimes--count  Chicago, Illinois
# 1  1600000US1714000--2006--Murder and nonnegligen...  Chicago, Illinois
# 2   1600000US1714000--2006--Aggravated assault--rate  Chicago, Illinois
# 3  1600000US1714000--2010--Murder and nonnegligen...  Chicago, Illinois
# 4             1600000US1714000--2009--Burglary--rate  Chicago, Illinois
#
#     place_name   type               value variable  year
# 0  Chicago, IL  place              268492    count  2010
# 1  Chicago, IL  place  16.376256387789752     rate  2006
# 2  Chicago, IL  place   610.4354544551115     rate  2006
# 3  Chicago, IL  place                 432    count  2010
# 4  Chicago, IL  place   930.1260939794574     rate  2009

# %%
Crime_DF['year'] = pd.to_numeric(Crime_DF['year'])
Crime_DF['value'] = pd.to_numeric(Crime_DF['value'])

# %%
Filter_crimetype = Crime_DF.loc[Crime_DF['crime_type'] == 'Violent crime']
Crime = Filter_crimetype.loc[Filter_crimetype['variable'] == 'rate']
Crime
# Out:
#         crime_type                id  \
# 26   Violent crime  1600000US1714000
# 169  Violent crime  1600000US1714000
# 170  Violent crime  1600000US1714000
# 183  Violent crime  1600000US1714000
# 232  Violent crime  1600000US1714000
#
#                                              key               name  \
# 26   1600000US1714000--2014--Violent crime--rate  Chicago, Illinois
# 169  1600000US1714000--2015--Violent crime--rate  Chicago, Illinois
# 170  1600000US1714000--2015--Violent crime--rate  Chicago, Illinois
# 183  1600000US1714000--2016--Violent crime--rate  Chicago, Illinois
# 232  1600000US1714000--2017--Violent crime--rate  Chicago, Illinois
#
#       place_name   type        value variable  year
# 26   Chicago, IL  place   884.285243     rate  2014
# 169  Chicago, IL  place   903.838648     rate  2015
# 170  Chicago, IL  place   903.838648     rate  2015
# 183  Chicago, IL  place  1105.479215     rate  2016
# 232          NaN  place  1098.858867     rate  2017

# %%
Crime.plot(kind='line', x='year', y='value', figsize=(15,7), color='Orange')

plt.xlim(2013, 2018)
plt.title('Crime Rate per 100,000 people')
plt.xlabel('Year')
plt.ylabel('Rate (Per 100,000 People)')
# Out:
# Text(0, 0.5, 'Rate (Per 100,000 People)')

# %%
#Seems that in 2014 Chicago reclassified thier crime statisitcs to start including 'Violent crimes'

# %%
csv = "Chicago_Graduation_Rates.csv"

Graduation_Rates = pd.read_csv(csv)
Chicago_Graduation_Rates = pd.DataFrame(Graduation_Rates)
Chicago_Graduation_Rates.head()
# Out:
#    ﻿Years  Graduation Rate
# 0    2010             79.4
# 1    2011             80.2
# 2    2012             80.5
# 3    2013             81.1
# 4    2014             81.6

# %%
Chicago_Graduation_Rates.plot(kind='line', x='Years', y='Graduation Rate', figsize=(15,10), color='maroon')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Years'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-3e9a002e6ff3> in <module>
# ----> 1 Chicago_Graduation_Rates.plot(kind='line', x='Years', y='Graduation Rate', figsize=(15,10), color='maroon')
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2940                           fontsize=fontsize, colormap=colormap, table=table,
#    2941                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2942                           sort_columns=sort_columns, **kwds)
#    2943     __call__.__doc__ = plot_frame.__doc__
#    2944
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1971                  yerr=yerr, xerr=xerr,
#    1972                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1973                  **kwds)
#    1974
#    1975
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1761                 if is_integer(x) and not data.columns.holds_integer():
#    1762                     x = data_cols[x]
# -> 1763                 elif not isinstance(data[x], ABCSeries):
#    1764                     raise ValueError("x must be a label or position")
#    1765                 data = data.set_index(x)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Years'

# %%
csv = "Chicago_Income_Rates.csv"

Income_Rates = pd.read_csv(csv)
Chicago_Income_Rates = pd.DataFrame(Income_Rates)
Chicago_Income_Rates.head()
# Out:
#    ﻿Years  < $10,000  $10,000 - $14,999  $15,000 - $24,999  $25,000 - $34,999  \
# 0    2010        1.9                4.9               16.3               16.8
# 1    2011        1.9                4.5               15.1               16.6
# 2    2012        1.8                4.2               14.9               16.2
# 3    2013        1.8                3.8               14.9               15.9
# 4    2014        1.8                3.6               14.8               15.6
#
#    $35,000 - $49,999  $50,000 - $64,999  $65,000 - $74,000  $75,000 - $99,999  \
# 0               19.5               14.3                6.4                9.3
# 1               19.3               14.8                6.6                9.9
# 2               18.8               15.0                6.5               10.2
# 3               18.5               14.8                6.6               10.7
# 4               18.5               14.4                6.9               11.1
#
#    > $100,000
# 0        10.7
# 1        11.5
# 2        12.3
# 3        13.0
# 4        13.4

# %%
# Calculating everyone under $25,000 appending them to 'Chicago_Income_Rate' Datafrome.
Chicago_Income_Rates['% in Poverty'] = Chicago_Income_Rates["< $10,000"]+ Chicago_Income_Rates["$10,000 - $14,999"]+ Chicago_Income_Rates["$15,000 - $24,999"]
Chicago_Income_Rates
# Out:
#    ﻿Years  < $10,000  $10,000 - $14,999  $15,000 - $24,999  $25,000 - $34,999  \
# 0    2010        1.9                4.9               16.3               16.8
# 1    2011        1.9                4.5               15.1               16.6
# 2    2012        1.8                4.2               14.9               16.2
# 3    2013        1.8                3.8               14.9               15.9
# 4    2014        1.8                3.6               14.8               15.6
# 5    2015        1.8                3.6               14.7               15.5
# 6    2016        1.6                3.4               14.2               15.2
# 7    2017        1.5                3.0               13.3               15.1
#
#    $35,000 - $49,999  $50,000 - $64,999  $65,000 - $74,000  $75,000 - $99,999  \
# 0               19.5               14.3                6.4                9.3
# 1               19.3               14.8                6.6                9.9
# 2               18.8               15.0                6.5               10.2
# 3               18.5               14.8                6.6               10.7
# 4               18.5               14.4                6.9               11.1
# 5               18.0               14.8                6.6               11.1
# 6               17.9               15.0                6.7               11.3
# 7               17.7               15.1                6.8               11.7
#
#    > $100,000  % in Poverty
# 0        10.7          23.1
# 1        11.5          21.5
# 2        12.3          20.9
# 3        13.0          20.5
# 4        13.4          20.2
# 5        13.9          20.1
# 6        14.8          19.2
# 7        15.9          17.8

# %%
Chicago_Income_Rates.plot(kind='line', x='Years', y='Graduation Rate', figsize=(15,10), color='maroon')
